# %%
import pandas as pd

# %%
df_titanic = pd.read_csv("/content/test.csv")

# %%
df_titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_titanic["Name"]
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df = df_titanic["Name", "Sex", "Age"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Name', 'Sex', 'Age')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-426a2d56eb7b> in <cell line: 1>()
# ----> 1 df = df_titanic["Name", "Sex", "Age"]
#
# ...

# %%
df_titanic[["Name", "Age", "Sex"]]
# Out:
#                                              Name   Age     Sex
# 0                                Kelly, Mr. James  34.5    male
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0  female
# 2                       Myles, Mr. Thomas Francis  62.0    male
# 3                                Wirz, Mr. Albert  27.0    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0  female
# ..                                            ...   ...     ...
# 413                            Spector, Mr. Woolf   NaN    male
# 414                  Oliva y Ocana, Dona. Fermina  39.0  female
# 415                  Saether, Mr. Simon Sivertsen  38.5    male
# 416                           Ware, Mr. Frederick   NaN    male
# 417                      Peter, Master. Michael J   NaN    male
#
# [418 rows x 3 columns]

# %%
newdf = df_titanic[["Name", "Age", "Sex"]]

# %%
newdf
# Out:
#                                              Name   Age     Sex
# 0                                Kelly, Mr. James  34.5    male
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0  female
# 2                       Myles, Mr. Thomas Francis  62.0    male
# 3                                Wirz, Mr. Albert  27.0    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0  female
# ..                                            ...   ...     ...
# 413                            Spector, Mr. Woolf   NaN    male
# 414                  Oliva y Ocana, Dona. Fermina  39.0  female
# 415                  Saether, Mr. Simon Sivertsen  38.5    male
# 416                           Ware, Mr. Frederick   NaN    male
# 417                      Peter, Master. Michael J   NaN    male
#
# [418 rows x 3 columns]

# %%
newdf["Age"].mean()
# Out:
# 30.272590361445783

# %%
newdf["Sex"].replace("male", 0).replace("female", 1)
# Out:
# <ipython-input-12-9487548d2642>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   newdf["Sex"].replace("male", 0).replace("female", 1)
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Sex, Length: 418, dtype: int64

# %%
passengers = len(newdf)

# %%
passengers
# Out:
# 418

# %%
print(f"The number of passengers is {passengers}")
# Out:
# The number of passengers is 418

# %%
rows = newdf.shape[0]

# %%
print(f"The number of passengers is {rows}")
# Out:
# The number of passengers is 418

# %%
num_of_rows = newdf.index.size

# %%
num_of_rows
# Out:
# 418

# %%
women = newdf[newdf["Sex"] == 1]

# %%
women
# Out:
# Empty DataFrame
# Columns: [Name, Age, Sex]
# Index: []

# %%
gender_counts = newdf["Sex"].value_counts()

# %%
gender_counts
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
print(f"Number of women on the Titanic was {gender_counts.get(1)}")
# Out:
# Number of women on the Titanic was 152
# <ipython-input-24-32de6585a8a5>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Number of women on the Titanic was {gender_counts.get(1)}")

# %%
print(f"Number of men on the Titanic was {gender_counts.get(0)}")
# Out:
# Number of men on the Titanic was 266
# <ipython-input-25-97726b4800f3>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Number of men on the Titanic was {gender_counts.get(0)}")

# %%
newdf["Year of birth"] = [1912 - elem for elem in newdf["Age"]]
# Out:
# <ipython-input-26-c8ef4f38e1ca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf["Year of birth"] = [1912 - elem for elem in newdf["Age"]]

# %%
df_titanic["Year of birth"] = [1912 - elem for elem in df_titanic["Age"]]

# %%
df_titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df_titanic[["Age", "Year of birth"]]
# Out:
#       Age  Year of birth
# 0    34.5         1877.5
# 1    47.0         1865.0
# 2    62.0         1850.0
# 3    27.0         1885.0
# 4    22.0         1890.0
# ..    ...            ...
# 413   NaN            NaN
# 414  39.0         1873.0
# 415  38.5         1873.5
# 416   NaN            NaN
# 417   NaN            NaN
#
# [418 rows x 2 columns]
